# %%
import os

import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import matplotlib.patches as mpatches

datafile = '../data/country_gdp_growth.csv'
shapefile = '../data/world_shape/ne_10m_admin_0_countries_lakes.shp'

colors = 9
cmap = 'RdYlGn'
figsize = (16, 10)
year = '2009'
cols = ['Country Name', 'Country Code', year]
title = 'Rast BDP držav v letu {}'.format(year)

# %%
world = gpd.read_file(shapefile)[['ADM0_A3', 'geometry']]
world.head()
# Out:
#   ADM0_A3                                           geometry
# 0     IDN  (POLYGON ((117.7036079039552 4.163414542001791...
# 1     MYS  (POLYGON ((117.7036079039552 4.163414542001791...
# 2     CHL  (POLYGON ((-69.51008875199994 -17.506588197999...
# 3     BOL  POLYGON ((-69.51008875199994 -17.5065881979999...
# 4     PER  (POLYGON ((-69.51008875199994 -17.506588197999...

# %%
df = pd.read_csv(datafile, skiprows=4, usecols=cols)
df.loc[df[year] > 0.5, [year]] = 1
df.loc[df[year] < -0.5, [year]] = -1
df
# Out:
#                                           Country Name Country Code      2009
# 0                                                Aruba          ABW -1.000000
# 1                                          Afghanistan          AFG  1.000000
# 2                                               Angola          AGO  1.000000
# 3                                              Albania          ALB  1.000000
# 4                                              Andorra          AND -1.000000
# 5                                           Arab World          ARB  0.465712
# 6                                 United Arab Emirates          ARE -1.000000
# 7                                            Argentina          ARG -1.000000
# 8                                              Armenia          ARM -1.000000
# 9                                       American Samoa          ASM -1.000000
# 10                                 Antigua and Barbuda          ATG -1.000000
# 11                                           Australia          AUS  1.000000
# 12                                             Austria          AUT -1.000000
# 13                                          Azerbaijan          AZE  1.000000
# 14                                             Burundi          BDI  1.000000
# 15                                             Belgium          BEL -1.000000
# 16                                               Benin          BEN  1.000000
# 17                                        Burkina Faso          BFA  1.000000
# 18                                          Bangladesh          BGD  1.000000
# 19                                            Bulgaria          BGR -1.000000
# 20                                             Bahrain          BHR  1.000000
# 21                                        Bahamas, The          BHS -1.000000
# 22                              Bosnia and Herzegovina          BIH -1.000000
# 23                                             Belarus          BLR  0.199995
# 24                                              Belize          BLZ  1.000000
# 25                                             Bermuda          BMU -1.000000
# 26                                             Bolivia          BOL  1.000000
# 27                                              Brazil          BRA -0.125775
# 28                                            Barbados          BRB -1.000000
# 29                                   Brunei Darussalam          BRN -1.000000
# ..                                                 ...          ...       ...
# 234  Latin America & the Caribbean (IDA & IBRD coun...          TLA -1.000000
# 235                                        Timor-Leste          TLS -1.000000
# 236  Middle East & North Africa (IDA & IBRD countries)          TMN  1.000000
# 237                                              Tonga          TON  1.000000
# 238                            South Asia (IDA & IBRD)          TSA  1.000000
# 239          Sub-Saharan Africa (IDA & IBRD countries)          TSS  1.000000
# 240                                Trinidad and Tobago          TTO -1.000000
# 241                                            Tunisia          TUN  1.000000
# 242                                             Turkey          TUR -1.000000
# 243                                             Tuvalu          TUV -1.000000
# 244                                           Tanzania          TZA  1.000000
# 245                                             Uganda          UGA  1.000000
# 246                                            Ukraine          UKR -1.000000
# 247                                Upper middle income          UMC  1.000000
# 248                                            Uruguay          URY  1.000000
# 249                                      United States          USA -1.000000
# 250                                         Uzbekistan          UZB  1.000000
# 251                     St. Vincent and the Grenadines          VCT -1.000000
# 252                                      Venezuela, RB          VEN -1.000000
# 253                             British Virgin Islands          VGB       NaN
# 254                              Virgin Islands (U.S.)          VIR -1.000000
# 255                                            Vietnam          VNM  1.000000
# 256                                            Vanuatu          VUT  1.000000
# 257                                              World          WLD -1.000000
# 258                                              Samoa          WSM -1.000000
# 259                                             Kosovo          XKX  1.000000
# 260                                        Yemen, Rep.          YEM  1.000000
# 261                                       South Africa          ZAF -1.000000
# 262                                             Zambia          ZMB  1.000000
# 263                                           Zimbabwe          ZWE  1.000000
#
# [264 rows x 3 columns]

# %%
merged = world.merge(df, left_on='ADM0_A3', right_on='Country Code')
merged.describe()
# Out:
#              2009
# count  200.000000
# mean    -0.008573
# std      0.983398
# min     -1.000000
# 25%     -1.000000
# 50%     -0.019539
# 75%      1.000000
# max      1.000000

# %%
fig = plt.figure()
ax = merged.dropna().plot(column=year, cmap=cmap, figsize=figsize, scheme='fisher_jenks', k=colors, legend=True)

merged[merged.isna().any(axis=1)].plot(ax=ax, facecolor='#A9A9A9')

ax.set_axis_off()
ax.set_title(title, fontdict={'fontsize': 20})

red_patch = mpatches.Patch(color='red', label='Negativna rast (< -0.5)')
green_patch = mpatches.Patch(color='green', label='Pozitivna rast (> 0.5)')
yellow_patch = mpatches.Patch(color='yellow', label='Nevtralna rast')
ax.legend(handles=[red_patch, green_patch, yellow_patch])
ax.get_legend().set_bbox_to_anchor((.12, .4))
ax.get_legend().set_title('BDP rast')

# %%
#ax.get_figure().savefig('../img/country_growth_fall_gdp_{}.png'.format(year), bbox_inches = "tight")
