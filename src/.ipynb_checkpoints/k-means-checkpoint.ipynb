# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

datafile = '../data/country_gdp_growth.csv'
year = '2009'
cols = ['Country Name', 'Country Code', year]
df = pd.read_csv(datafile, skiprows=4, usecols=cols)

#df[df[year].isna()]
df = df.dropna()
df
# Out:
#                                           Country Name Country Code       2009
# 0                                                Aruba          ABW -10.519748
# 1                                          Afghanistan          AFG  21.390528
# 2                                               Angola          AGO   0.858713
# 3                                              Albania          ALB   3.350000
# 4                                              Andorra          AND  -3.690654
# 5                                           Arab World          ARB   0.465712
# 6                                 United Arab Emirates          ARE  -5.242922
# 7                                            Argentina          ARG  -5.918525
# 8                                              Armenia          ARM -14.149989
# 9                                       American Samoa          ASM  -4.237288
# 10                                 Antigua and Barbuda          ATG -12.107537
# 11                                           Australia          AUS   1.922727
# 12                                             Austria          AUT  -3.764580
# 13                                          Azerbaijan          AZE   9.410654
# 14                                             Burundi          BDI   3.812747
# 15                                             Belgium          BEL  -2.253175
# 16                                               Benin          BEN   2.329301
# 17                                        Burkina Faso          BFA   2.962014
# 18                                          Bangladesh          BGD   5.045125
# 19                                            Bulgaria          BGR  -3.586146
# 20                                             Bahrain          BHR   2.539772
# 21                                        Bahamas, The          BHS  -4.175260
# 22                              Bosnia and Herzegovina          BIH  -3.002753
# 23                                             Belarus          BLR   0.199995
# 24                                              Belize          BLZ   0.670801
# 25                                             Bermuda          BMU  -5.284177
# 26                                             Bolivia          BOL   3.357001
# 27                                              Brazil          BRA  -0.125775
# 28                                            Barbados          BRB  -3.972928
# 29                                   Brunei Darussalam          BRN  -1.764536
# ..                                                 ...          ...        ...
# 233                                       Turkmenistan          TKM   6.100000
# 234  Latin America & the Caribbean (IDA & IBRD coun...          TLA  -1.899595
# 235                                        Timor-Leste          TLS  -6.055189
# 236  Middle East & North Africa (IDA & IBRD countries)          TMN   2.517372
# 237                                              Tonga          TON   2.290613
# 238                            South Asia (IDA & IBRD)          TSA   7.605875
# 239          Sub-Saharan Africa (IDA & IBRD countries)          TSS   3.014172
# 240                                Trinidad and Tobago          TTO  -4.390592
# 241                                            Tunisia          TUN   3.043449
# 242                                             Turkey          TUR  -4.704445
# 243                                             Tuvalu          TUV  -4.432851
# 244                                           Tanzania          TZA   5.382346
# 245                                             Uganda          UGA   6.801517
# 246                                            Ukraine          UKR -14.758545
# 247                                Upper middle income          UMC   1.730896
# 248                                            Uruguay          URY   4.243494
# 249                                      United States          USA  -2.775530
# 250                                         Uzbekistan          UZB   8.100000
# 251                     St. Vincent and the Grenadines          VCT  -2.099061
# 252                                      Venezuela, RB          VEN  -3.202303
# 254                              Virgin Islands (U.S.)          VIR  -6.641493
# 255                                            Vietnam          VNM   5.397898
# 256                                            Vanuatu          VUT   3.312816
# 257                                              World          WLD  -1.733287
# 258                                              Samoa          WSM  -4.808272
# 259                                             Kosovo          XKX   3.341666
# 260                                        Yemen, Rep.          YEM   3.866230
# 261                                       South Africa          ZAF  -1.538089
# 262                                             Zambia          ZMB   9.220348
# 263                                           Zimbabwe          ZWE  12.019561
#
# [248 rows x 3 columns]
