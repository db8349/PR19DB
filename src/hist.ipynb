# %%
import pandas as pd
import matplotlib.pyplot as plt

datafile = '../data/country_gdp_growth.csv'
year = '2009'
cols = ['Country Name', 'Country Code', year]
df = pd.read_csv(datafile, skiprows=4, usecols=cols)

df = df.dropna()
df = df.sort_values(by=[year], ascending=True)
df
# Out:
#                                       Country Name Country Code       2009
# 162                       Northern Mariana Islands          MNP -17.531120
# 141                                      Lithuania          LTU -14.814163
# 246                                        Ukraine          UKR -14.758545
# 69                                         Estonia          EST -14.724404
# 143                                         Latvia          LVA -14.401692
# 8                                          Armenia          ARM -14.149989
# 210                                     San Marino          SMR -12.824675
# 10                             Antigua and Barbuda          ATG -12.107537
# 147                                         Monaco          MCO -11.317507
# 0                                            Aruba          ABW -10.519748
# 73                                         Finland          FIN  -8.269037
# 200                             Russian Federation          RUS  -7.820885
# 220                                       Slovenia          SVN  -7.797277
# 31                                        Botswana          BWA  -7.652310
# 97                                         Croatia          HRV  -7.291431
# 150                                       Maldives          MDV  -7.228841
# 50                                  Cayman Islands          CYM  -7.200495
# 125                                         Kuwait          KWT  -7.076103
# 254                          Virgin Islands (U.S.)          VIR  -6.641493
# 88                                         Grenada          GRD  -6.613281
# 99                                         Hungary          HUN  -6.599974
# 112                                        Iceland          ISL  -6.505254
# 235                                    Timor-Leste          TLS  -6.055189
# 148                                        Moldova          MDA  -6.000000
# 62   Europe & Central Asia (excluding high income)          ECA  -5.991199
# 186                                          Palau          PLW  -5.929866
# 7                                        Argentina          ARG  -5.918525
# 199                                        Romania          ROU  -5.910360
# 160                                     Montenegro          MNE  -5.800000
# 53                                         Germany          DEU  -5.618860
# ..                                             ...          ...        ...
# 103                                      IDA blend          IDB   5.749769
# 233                                   Turkmenistan          TKM   6.100000
# 180                                           Oman          OMN   6.112454
# 201                                         Rwanda          RWA   6.284855
# 163                                     Mozambique          MOZ   6.351462
# 84                                     Gambia, The          GMB   6.449696
# 30                                          Bhutan          BTN   6.657224
# 245                                         Uganda          UGA   6.801517
# 187                               Papua New Guinea          PNG   6.805554
# 42                                     Congo, Rep.          COG   7.468942
# 127                                        Lao PDR          LAO   7.501775
# 202                                     South Asia          SAS   7.605875
# 238                        South Asia (IDA & IBRD)          TSA   7.605875
# 59     East Asia & Pacific (excluding high income)          EAP   7.697311
# 228     East Asia & Pacific (IDA & IBRD countries)          TEA   7.697989
# 172                                        Nigeria          NGA   8.036925
# 250                                     Uzbekistan          UZB   8.100000
# 166                                         Malawi          MWI   8.328110
# 107                                          India          IND   8.479784
# 177                                          Nauru          NRU   8.659698
# 194                             West Bank and Gaza          PSE   8.662535
# 70                                        Ethiopia          ETH   8.802553
# 262                                         Zambia          ZMB   9.220348
# 38                                           China          CHN   9.399813
# 13                                      Azerbaijan          AZE   9.410654
# 128                                        Lebanon          LBN  10.054477
# 158                                        Myanmar          MMR  10.550009
# 198                                          Qatar          QAT  11.956561
# 263                                       Zimbabwe          ZWE  12.019561
# 1                                      Afghanistan          AFG  21.390528
#
# [248 rows x 3 columns]

# %%
f, ax = plt.subplots(figsize=(45, 10))
ax.bar(df['Country Code'], df[year])
ax.tick_params(axis='x', rotation=90)
