# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

datafile = '../data/country_exports.csv'
year = '2008'
next_year = str(int(year) + 1)
cols = ['Country Name', 'Country Code', year, next_year]
df = pd.read_csv(datafile, skiprows=4, usecols=cols)

df = df.dropna()
df = df.sort_values(by=[year, next_year], ascending=True)
df
# Out:
#                                           Country Name Country Code  \
# 243                                             Tuvalu          TUV
# 217                              Sao Tome and Principe          STP
# 122                                           Kiribati          KIR
# 153                                   Marshall Islands          MHL
# 237                                              Tonga          TON
# 235                                        Timor-Leste          TLS
# 44                                             Comoros          COM
# 186                                              Palau          PLW
# 14                                             Burundi          BDI
# 55                                            Dominica          DMA
# 85                                       Guinea-Bissau          GNB
# 258                                              Samoa          WSM
# 88                                             Grenada          GRD
# 251                     St. Vincent and the Grenadines          VCT
# 123                                St. Kitts and Nevis          KNA
# 207                                    Solomon Islands          SLB
# 256                                            Vanuatu          VUT
# 84                                         Gambia, The          GMB
# 208                                       Sierra Leone          SLE
# 54                                            Djibouti          DJI
# 131                                          St. Lucia          LCA
# 10                                 Antigua and Barbuda          ATG
# 30                                              Bhutan          BTN
# 45                                          Cabo Verde          CPV
# 129                                            Liberia          LBR
# 259                                             Kosovo          XKX
# 24                                              Belize          BLZ
# 224                                         Seychelles          SYC
# 98                                               Haiti          HTI
# 139                                            Lesotho          LSO
# ..                                                 ...          ...
# 126  Latin America & Caribbean (excluding high income)          LAC
# 75                                              France          FRA
# 117                                              Japan          JPN
# 234  Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 62       Europe & Central Asia (excluding high income)          ECA
# 137                                Lower middle income          LMC
# 132                          Latin America & Caribbean          LCN
# 5                                           Arab World          ARB
# 229       Europe & Central Asia (IDA & IBRD countries)          TEC
# 38                                               China          CHN
# 53                                             Germany          DEU
# 249                                      United States          USA
# 228         East Asia & Pacific (IDA & IBRD countries)          TEA
# 59         East Asia & Pacific (excluding high income)          EAP
# 60                          Early-demographic dividend          EAR
# 168                                      North America          NAC
# 247                                Upper middle income          UMC
# 140                          Late-demographic dividend          LTE
# 61                                 East Asia & Pacific          EAS
# 154                                      Middle income          MIC
# 138                                Low & middle income          LMY
# 100                                          IBRD only          IBD
# 66                                           Euro area          EMU
# 101                                   IDA & IBRD total          IBT
# 71                                      European Union          EUU
# 63                               Europe & Central Asia          ECS
# 196                          Post-demographic dividend          PST
# 179                                       OECD members          OED
# 93                                         High income          HIC
# 257                                              World          WLD
#
#              2008          2009
# 243  4.060751e+06  5.513225e+06
# 217  1.750938e+07  1.961283e+07
# 122  2.074754e+07  1.981626e+07
# 153  2.976058e+07  3.093420e+07
# 237  5.142615e+07  4.370721e+07
# 235  5.814386e+07  6.614993e+07
# 44   7.412961e+07  7.770118e+07
# 186  9.957236e+07  9.253324e+07
# 14   1.529724e+08  1.183460e+08
# 55   1.567337e+08  1.479492e+08
# 85   1.719019e+08  1.547613e+08
# 258  1.801318e+08  1.736050e+08
# 88   2.078008e+08  1.872373e+08
# 251  2.101683e+08  1.923077e+08
# 123  2.346875e+08  1.747756e+08
# 207  2.593981e+08  2.240891e+08
# 256  2.754389e+08  3.034894e+08
# 84   3.230796e+08  2.784015e+08
# 208  3.304592e+08  3.683095e+08
# 54   3.657024e+08  3.994069e+08
# 131  5.360585e+08  5.439521e+08
# 10   6.253687e+08  5.616235e+08
# 30   6.536378e+08  5.742688e+08
# 45   7.100981e+08  5.624722e+08
# 129  7.585699e+08  4.540728e+08
# 259  7.959498e+08  9.712245e+08
# 24   8.665658e+08  7.282999e+08
# 224  9.020698e+08  8.497945e+08
# 98   9.171957e+08  1.034007e+09
# 139  9.323831e+08  7.756843e+08
# ..            ...           ...
# 126  8.128956e+11  6.382040e+11
# 75   8.273200e+11  6.646401e+11
# 117  8.901581e+11  6.690594e+11
# 234  1.012905e+12  8.021692e+11
# 62   1.081426e+12  7.558998e+11
# 137  1.100409e+12  8.969903e+11
# 132  1.127137e+12  8.907122e+11
# 5    1.282702e+12  8.650765e+11
# 229  1.313630e+12  9.428595e+11
# 38   1.495317e+12  1.249724e+12
# 53   1.639837e+12  1.297255e+12
# 249  1.841613e+12  1.583051e+12
# 228  2.222202e+12  1.871461e+12
# 59   2.224909e+12  1.873732e+12
# 60   2.318200e+12  1.802018e+12
# 168  2.378852e+12  1.976112e+12
# 247  4.194159e+12  3.283027e+12
# 140  4.356490e+12  3.484333e+12
# 61   5.109145e+12  4.225623e+12
# 154  5.295618e+12  4.181357e+12
# 138  5.393543e+12  4.262768e+12
# 100  5.479479e+12  4.331967e+12
# 66   5.659692e+12  4.519109e+12
# 101  5.824001e+12  4.612008e+12
# 71   7.487605e+12  5.963102e+12
# 63   9.055010e+12  7.120226e+12
# 196  1.253033e+13  1.008311e+13
# 179  1.262921e+13  1.014946e+13
# 93   1.454218e+13  1.166971e+13
# 257  1.993232e+13  1.592958e+13
#
# [223 rows x 4 columns]

# %%
top_economies = ['USA', 'CHN', 'JPN', 'DEU', 'GIB', 'IND', 'FRA', 'BRA', 'ITA', 'CAN']
df = df[df['Country Code'].isin(top_economies)]

f, ax = plt.subplots()
ax.bar(df['Country Name'], df[year], color='green')
ax.bar(df['Country Name'], df[next_year], color='palegreen')
ax.tick_params(axis='x', rotation=90)
ax.set_title('Vrednost izvozov 10 držav z največjimi ekonomijami ({}-{})'.format(year, next_year))
ax.set_ylabel('Vrednost izvozov v bilijonih')

green_patch = mpatches.Patch(color='green', label='Vrednost izvoza leta {}'.format(year))
pgreen_patch = mpatches.Patch(color='palegreen', label='Vrednost izvoza leta {}'.format(next_year))
ax.legend(handles=[green_patch, pgreen_patch])
ax.get_legend().set_title('Vrednost izvozov')
ax.yaxis.get_offset_text().set_visible(False)

# %%
ax.get_figure().savefig('../img/country_exports_({}-{}).png'.format(year, next_year), bbox_inches = "tight")
